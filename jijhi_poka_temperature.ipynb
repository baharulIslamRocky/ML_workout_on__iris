# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as nm
import seaborn as sns

# %%
import os
for direc,_,files in os.walk('G:/MINE/SUB/Thesis/'):
    for file in files:
        print(os.path.join(direc,file))
# Out:
# G:/MINE/SUB/Thesis/2709_38454_bundle_archive (1).zip
# G:/MINE/SUB/Thesis/Hands-On Machine Learning with Scikit-Learn and TensorFlow ver 1.pdf
# G:/MINE/SUB/Thesis/handson-ml-master.zip
# G:/MINE/SUB/Thesis/melb_data.csv
# G:/MINE/SUB/Thesis/New Microsoft Excel Worksheet.csv
# G:/MINE/SUB/Thesis/Python-for-Data-Analysis.-Data-Wrangling-with-Pandas-NumPy-and-IPython-2017-OReilly (1).pdf
# G:/MINE/SUB/Thesis/Data Set\California_housing.csv
# G:/MINE/SUB/Thesis/Friday Practice\iowa house label encoding.ipynb
# G:/MINE/SUB/Thesis/Friday Practice\iowa house pipeline.ipynb
# G:/MINE/SUB/Thesis/Friday Practice\Untitled.ipynb
# G:/MINE/SUB/Thesis/Friday Practice\.ipynb_checkpoints\iowa house label encoding-checkpoint.ipynb
# G:/MINE/SUB/Thesis/Friday Practice\.ipynb_checkpoints\iowa house pipeline-checkpoint.ipynb
# G:/MINE/SUB/Thesis/Friday Practice\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# G:/MINE/SUB/Thesis/Hands on ML\5227_7876_bundle_archive.zip
# ...

# %%
data=pd.read_csv('G:/MINE/SUB/Thesis/Rakib Python SK_learn\dataset\chirps.csv')

# %%
data.iloc[:5]
# Out:
#      Date  Time  Chirps_15s  Temp_C
# 0  21-Aug  2030        44.0  26.944
# 1  21-Aug  2100        46.4  25.833
# 2  21-Aug  2200        43.6  25.556
# 3  24-Aug  1945        35.0  23.056
# 4  24-Aug  2015        35.0  21.389

# %%
plt.figure(figsize=(7,5))
sns.lineplot(x=data['Chirps_15s'],y=data['Temp_C'])
# Out:
# <AxesSubplot:xlabel='Chirps_15s', ylabel='Temp_C'>

# %%
plt.figure(figsize=(17,5))
sns.barplot(x=data['Chirps_15s'],y=data['Temp_C'])
# Out:
# <AxesSubplot:xlabel='Chirps_15s', ylabel='Temp_C'>

# %%
plt.figure(figsize=(17,5))
sns.scatterplot(x=data['Chirps_15s'],y=data['Temp_C'])
# Out:
# <AxesSubplot:xlabel='Chirps_15s', ylabel='Temp_C'>

# %%
plt.figure(figsize=(17,5))
sns.regplot(x=data['Chirps_15s'],y=data['Temp_C'])
# Out:
# <AxesSubplot:xlabel='Chirps_15s', ylabel='Temp_C'>

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x=data['Chirps_15s'],y=data['Temp_C'],shade=True)
# Out:
# <AxesSubplot:xlabel='Chirps_15s', ylabel='Temp_C'>

# %%
plt.figure(figsize=(17,5))
sns.lmplot(x='Chirps_15s',y='Temp_C',data=data)

# %%
x=list(data['Chirps_15s'])
y=list(data['Temp_C'])

# %%
plt.plot(y,x)
plt.show()

# %%
plt.grid(True)
plt.plot(y,x)
plt.show()

# %%
plt.grid(True)
plt.plot(x,y,'ro')
plt.show()
